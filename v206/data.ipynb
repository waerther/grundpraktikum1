# %%
import pandas as pd

messdaten = pd.read_excel("Messdaten.xlsx")
daten = messdaten.iloc[:, [0,1,2,5,7,8]] 
print(messdaten.to_latex(index = False))
# Out:
# \begin{tabular}{rrrrrrrrrrrr}
# \toprule
#  t(s) &  t**2(s**2) &  T\_1 (C) &  T\_2 (C)  &  T\_1 (K) &  T\_2 (K) &  p\_a (bar) &  p\_b (bar) &  p\_a+ (Pa) &  p\_b+ (Pa) &  P (W) &  1/T\_1 (1/K) \\
# \midrule
#     0 &           0 &     21.5 &      21.5 &   294.65 &   294.65 &        4.2 &        3.8 &   520000.0 &   480000.0 &    NaN &     0.003394 \\
#    60 &        3600 &     23.3 &      20.7 &   296.45 &   293.85 &        3.9 &        5.3 &   490000.0 &   630000.0 &    NaN &     0.003373 \\
#   120 &       14400 &     24.7 &      19.3 &   297.85 &   292.45 &        3.6 &        5.9 &   460000.0 &   690000.0 &    NaN &     0.003357 \\
#   180 &       32400 &     26.4 &      17.7 &   299.55 &   290.85 &        3.6 &        6.0 &   460000.0 &   700000.0 &    NaN &     0.003338 \\
#   240 &       57600 &     27.9 &      16.6 &   301.05 &   289.75 &        3.6 &        6.4 &   460000.0 &   740000.0 &    NaN &     0.003322 \\
# ...
